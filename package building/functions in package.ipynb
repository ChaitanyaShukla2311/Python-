# %%
from string111 import strfunctions

# %%
a='hello'
strfunctions.rev(a)
# Out:
# olleh

# %%
strfunctions.vowel_in(a)
# Out:
# {'e', 'o'}

# %%
strfunctions.len_of(a)
# Out:
# 5

# %%
strfunctions.is_palindrome(a)
# Out:
# False

# %%
strfunctions.to_lower(a)
# Out:
# 'hello'

# %%
strfunctions.to_upper(a)
# Out:
# 'HELLO'

# %%
strfunctions.word_in(a)
# Out:
# ['hello']

# %%
strfunctions.to_ascii(a)
# Out:
# <generator object to_ascii.<locals>.<genexpr> at 0x000002850890ECF0>
